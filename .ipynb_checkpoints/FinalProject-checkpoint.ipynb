# %% [markdown]
# # DATA301 Final Project

# %% [markdown]
# **Team name** Datatouille
#
# **Team members** Zack Soucek - zsoucek@calpoly.edu | Ryan Maier - rdmaier@calpoly.edu | Sean Tomer - stomerho@calpoly.edu
#
# **Dataset** StudentsPerformance.csv - https://www.kaggle.com/datasets/spscientist/students-performance-in-exams

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from collections import Counter
# %matplotlib inline

#####

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import make_pipeline
import itertools

# %%
spdf = pd.read_csv("./StudentsPerformance.csv")
spdf.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# Define numeric and categorical variable column names

numeric = ["math score","reading score","writing score"]
categorical = ['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course']

# %% [markdown]
# ## PREDICT CATEGORICAL VARIABLES BASED ON NUMERIC VARIABLES

# %% [markdown]
# **Question 1** Using KNeighborsClassifier, how well can we classify each categorical variable based on a student's reading, writing, and math scores?

# %%
for c in categorical:

    y = spdf[c]

    X = spdf[numeric]

    scaler = StandardScaler()
    model = KNeighborsClassifier(n_neighbors=50)
    pipeline = make_pipeline(scaler, model)

    scores_acc = cross_val_score(pipeline, X, y, cv=5, scoring="accuracy")
    print('Accuracy for '+c+':  '+str(scores_acc.mean()))
# Out:
# Accuracy for gender:  0.8539999999999999
# Accuracy for race/ethnicity:  0.304
# Accuracy for parental level of education:  0.231
# Accuracy for lunch:  0.702
# Accuracy for test preparation course:  0.6839999999999999

# %% [markdown]
# Gender can be predicted most accurately.

# %%
# Visualization of Test Scores between Males and Females

males = spdf[spdf['gender']=='male']
females = spdf[spdf['gender']=='female']

fig, axs = plt.subplots(3,2,figsize=(5,10))
for i in range(len(numeric)):
    c = numeric[i]
    axs[i,0].boxplot(males[c])
    axs[i,0].set_title('males - '+c)
    axs[i,1].boxplot(females[c])
    axs[i,1].set_title('females - '+c)

# %% [markdown]
# **Explanation**
#
# All of our predictions were found by using the three numeric variables to try and predict each of the categorical variables. By far our most accurate prediction was for gender with an 85.4% accuracy, followed by lunch and test preparation with a 70.2% and a 68.4% accuracy respectively. This shows us that this type of prediction struggles with predicting categorical variables with a large number of variables to choose from. The box plot shows the distribution of the test scores for each gender in each of the sections.

# %% [markdown]
# ## PREDICT NUMERIC VARIABLES BASED ON CATEGORICAL VARIABLES

# %% [markdown]
# **Queastion 2** Using both KNeighborsRegressor and LinearRegressor, how well can we predict a student's test performance based on all of the categorical variables?

# %%
# Select best K values for KNeighborsRegressor and each test subject

X = spdf[categorical]

encoder = make_column_transformer(
    (OneHotEncoder(sparse=False, handle_unknown="ignore"), 
     categorical),
    remainder="passthrough",
)
scaler = StandardScaler()

ks = []

for n in numeric:
    
    y = spdf[n]
    bestk = [1000,1000]

    for k in range(5,100):

        model_knr = KNeighborsRegressor(n_neighbors=k)
        pipeline_knr = make_pipeline(encoder, scaler, model_knr)

        # Calculate MSE

        mse_knr = np.mean(-cross_val_score(
            pipeline_knr, X, y, 
            cv=10, scoring="neg_mean_squared_error"
        ))
        
        if bestk[1]>mse_knr:
            bestk = [k,mse_knr]
            
    print("Best "+n+" k is "+str(bestk[0])+" with an MSE of "+str(bestk[1]))
    ks.append(bestk[0])
# Out:
# Best math score k is 52 with an MSE of 185.2420377218935
# Best reading score k is 52 with an MSE of 176.23844489644972
# Best writing score k is 52 with an MSE of 169.28088313609467

# %%
# Predict Test Scores and compare cross validation error between KNeighborsRegressor and LinearRegression

encoder = make_column_transformer(
    (OneHotEncoder(sparse=False, handle_unknown="ignore"), 
     categorical),
    remainder="passthrough",
)
scaler = StandardScaler()

for i in range(len(numeric)):
    
    n = numeric[i]

    y = spdf[n]

    X = spdf[categorical]
    
    # Build Pipelines
    
    k = ks[i]

    model_knr = KNeighborsRegressor(n_neighbors=k)
    model_lr = LinearRegression()
    pipeline_knr = make_pipeline(encoder, scaler, model_knr)
    pipeline_lr = make_pipeline(encoder, scaler, model_lr)

    # Calculate MSE

    mse_knr = np.mean(-cross_val_score(
        pipeline_knr, X, y, 
        cv=10, scoring="neg_mean_squared_error"
    ))
    print('KNeighborsRegressor MSE for '+n+', k=:'+str(k)+'  '+str(mse_knr))
    
    mse_lr = np.mean(-cross_val_score(
        pipeline_lr, X, y, 
        cv=10, scoring="neg_mean_squared_error"
    ))
    print('LinearRegression MSE for '+n+':  '+str(mse_lr))
# Out:
# KNeighborsRegressor MSE for math score, k=:52  185.2420377218935
# LinearRegression MSE for math score:  176.58034859708678
# KNeighborsRegressor MSE for reading score, k=:52  176.23844489644972
# LinearRegression MSE for reading score:  169.31062923666352
# KNeighborsRegressor MSE for writing score, k=:52  169.28088313609467
# LinearRegression MSE for writing score:  158.61475617156944

# %% [markdown]
# LinearRegression appears to perform better than KNeighborsRegressor when predicting the test scores.

# %%
# Visualize predictions using LinearRegression

encoder = make_column_transformer(
    (OneHotEncoder(sparse=False, handle_unknown="ignore"), 
     categorical),
    remainder="passthrough",
)
scaler = StandardScaler()

fig,axs = plt.subplots(1, 3, figsize=(18,5))

for i in range(len(numeric)):
    
    n = numeric[i]

    y = spdf[n]

    X = spdf[categorical]
    
    encoder.fit(X)
    X_enc = encoder.transform(X)
    scaler.fit(X_enc)
    X_sc = scaler.transform(X_enc)
    model_lr.fit(X_sc,y)
    preds = model_lr.predict(X_sc)
    
    clrmap = {'male':'b','female':'r'}
    axs[i].set_title("")
    axs[i].scatter(x=preds,y=y,c=X['gender'].map(clrmap),alpha=0.2)
    axs[i].plot([0,100],[0,100])
    axs[i].set_xlabel('Predicted '+n+' Score')
    axs[i].set_ylabel('Actual '+n+' Score')

# %% [markdown]
# **Explanation**
#
# The different predictions achieved similar quality, but not exactly the same accuracy. The most accurate model is the LinearRegression for the writing score, with a MSE of 158.61. These models are based on all columns, not including the score they are predicting. These graphs show the relationship between each predicted score, and the actual range of scores in the data set. The graphs show a clear linear relationship, but with thickness. This indicates that the predictions are accurate, but the ground truth has more variation. The graph shows more spread in the Y-axis(the Actual socres), to indicate this.

# %% [markdown]
# ## CLUSTERING FOR CATEGORICAL VARIABLES

# %% [markdown]
# **Question 3** How accurately does KMeans clustering apply to each categorical variable when all other variables are used to cluster the data into the same number of groups as the target variable has unique values?

# %%
# Clustering each categorical variable based on all of the others and comparing accuracies

for cluster_cat in categorical:

    X = spdf.drop(['parental level of education'], axis=1)

    y = spdf[cluster_cat]
    
    # Setup model

    catigs = [ x for x in X.columns if X[x].dtype!=int ]
    encoder = make_column_transformer(
        (OneHotEncoder(sparse=False, handle_unknown="ignore"), 
         catigs),
        remainder="passthrough",
    )
    scaler = StandardScaler()

    model = KMeans(n_clusters=len(y.value_counts()))
    
    # Train and predict

    encoder.fit(X)
    X_enc = encoder.transform(X)
    scaler.fit(X_enc)
    X_sc = scaler.transform(X_enc)
    model.fit(X_sc)
    preds = model.predict(X_sc)

    # Analyze cluster accuracy

    clusters = pd.DataFrame()
    clusters['predicted'] = preds
    clusters['actual'] = y

    pcnt_sum = 0

    for p in range(len(y.value_counts())):
        clust = clusters[clusters['predicted']==p]
        counts = clust.value_counts()
        pcnt = 100*round(counts.loc[p][0] / len(clust),5)
        pcnt_sum += pcnt
    pcnt_avg = pcnt_sum / len(y.value_counts())
    print('Average cluster accuracy for '+cluster_cat+': '+str(pcnt_avg)+' %')
# Out:
# Average cluster accuracy for gender: 60.833 %
# Average cluster accuracy for race/ethnicity: 32.275999999999996 %
# Average cluster accuracy for parental level of education: 24.435333333333336 %
# Average cluster accuracy for lunch: 70.8575 %
# Average cluster accuracy for test preparation course: 66.461 %

# %% [markdown]
# The lunch variable appears to cluster the best with a cluster accuracy of about 71%

# %% [markdown]
# **Explanation**
#
# The different predictions found by applying all other variables to cluster the data all varied in accuracy. The most accurate was the type of lunch with a 70.85% accuracy, which became our most accurate way of predicting it. Although race/ethnicity and parental level of education had the lowest accuracy in the cluster, it was still our most accurate way of measuring them.

# %% [markdown]
# ## DETERMINING THE BEST PREDICTORS OF EACH CATEGORICAL VARIABLE

# %% [markdown]
# **Question 4** Which independent variables are the best and worst predictors for each categorical variable?

# %%
# Determine which collection of variables is best able to classify each categorical variable

for c in categorical:
    
    y = spdf[c]

    features = spdf.drop([c], axis=1).columns

    # Assemble all possible combinations of features with which to predict the lunch plan

    combos = []
    combo_series = pd.Series(dtype=object)
    for L in range(1, len(features)+1):
        combo = itertools.combinations(features,L)
        for sub in combo:
            combos.append(list(sub))
    combo_series = pd.Series(combos)

    combo_accuracies = []
    
    # Try each combination of predictors and test their accuracies

    for columns in combo_series:

        X = spdf[columns]

        catigs = [ x for x in X.columns if X[x].dtype!=int ]
        encoder = make_column_transformer(
            (OneHotEncoder(sparse=False, handle_unknown="ignore"), 
             catigs),
            remainder="passthrough",
        )
        scaler = StandardScaler()
        model = KNeighborsClassifier(n_neighbors=ks[0])
        pipeline = make_pipeline(encoder, scaler, model)

        scores_acc = cross_val_score(pipeline, X, y, cv=5, scoring="accuracy")

        combo_accuracies.append([columns, scores_acc.mean()])
        
    # Determin which combination of predictors were the best and worst at predicting this variable

    sorted = pd.DataFrame(combo_accuracies, columns=['columns', 'accuracy']).sort_values('accuracy').reset_index()

    print(c)
    print("    Best predictors")
    print("        "+str(sorted['columns'][len(sorted)-1]))
    print("        Accuracy: "+str(round(100*sorted['accuracy'][len(sorted)-1],5))+" %")
    print("    Worst predictors")
    print("        "+str(sorted['columns'][0]))
    print("        Accuracy: "+str(round(100*sorted['accuracy'][0],5))+" %")
    print()
# Out:
# gender
#     Best predictors
#         ['test preparation course', 'math score', 'writing score']
#         Accuracy: 87.2 %
#     Worst predictors
#         ['lunch']
#         Accuracy: 45.8 %
#
# race/ethnicity
#     Best predictors
#         ['gender', 'test preparation course', 'math score']
#         Accuracy: 32.5 %
#     Worst predictors
#         ['lunch', 'test preparation course', 'reading score']
#         Accuracy: 27.5 %
#
# parental level of education
#     Best predictors
#         ['gender', 'test preparation course', 'reading score', 'writing score']
#         Accuracy: 24.2 %
#     Worst predictors
#         ['race/ethnicity', 'lunch', 'math score']
#         Accuracy: 19.0 %
#
# lunch
#     Best predictors
#         ['math score']
#         Accuracy: 70.3 %
#     Worst predictors
#         ['race/ethnicity', 'test preparation course', 'reading score', 'writing score']
#         Accuracy: 62.2 %
#
# test preparation course
#     Best predictors
# ...

# %% [markdown]
# **Explanation**
#
# By finding the best categories to use to predict each category, we basically find the highest and lowest level of accuracy possible, given the prediction methods used. The prediction with the highest accuracy was gender at 87.2% using test preparation course, math score, and writing score. The prediction with the lowest accuracy was parental level of education at 19% using race/ethnicity, lunch, and math score. Although we can generally predict gender accurately, even at their best, the predictions for race/ethnicity and parental level of education are never greater than 35% accuracy which tells us that there is no great way to predict them with the data used.
